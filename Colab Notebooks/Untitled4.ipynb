# %%
x=[1, 2, 3, 4, 5]
y=[i **2 for i in x]

plt.plot(x, y)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a3df5c29730f> in <module>()
#       2 y=[i **2 for i in x]
#       3
# ----> 4 plt.plot(x, y)
#       5
#       6 plt.show()
#
# NameError: name 'plt' is not defined
