# %%
a=21
b=23
c=a+b
print(c)
# Out:
# 44

# %%
a=[1, 2, 3, 4, 5]
c=[i **2 for i in a]

plt.plot(a, c)

show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cc3b9f1737ee> in <module>()
#       2 c=[i **2 for i in a]
#       3
# ----> 4 plt.plot(a, c)
#       5
#       6 plt.show()
#
# NameError: name 'plt' is not defined
