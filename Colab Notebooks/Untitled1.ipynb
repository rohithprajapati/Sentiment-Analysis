# %%
a=340       #assignments;no output
a            #print the value of a
# Out:
# 340

# %%
b="Rohith"         #assignments;no output
b                  #print the value of b
# Out:
# 'Rohith'

# %%
a=340
a
b="Rohith"
b                #print the value of b only
print(a,b)
# Out:
# 340 Rohith

# %%
a=120
b=36

c=a+b
print(c)
# Out:
# 156

# %%
a=360
b=48

c=a*b
print(c)
# Out:
# 17280

# %%
a=520
b=33

c=a/b
print(c)
# Out:
# 15.757575757575758

# %%
a=4
b=3

c=a**b
print(c)
# Out:
# 64

# %%
a=12
b=4

c=a-b
print(c)
# Out:
# 8

# %% [markdown]
# # New Section

# %%
x1 = [0.5,1.5,22.5,3.5]
y1 = [50,60,70,80]

plt.bar(x1, y1, label="BMW", color='r')

x2 = [.75,1.75,2.75,3.75,4.75]
y2 = [90,20,30,50,60]

plt.xlabel('Days')
plt.ylabel('Distance')
plt.tittle('Information')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-dbdd2a735190> in <module>()
#       2 y1 = [50,60,70,80]
#       3
# ----> 4 plt.bar(x1, y1, label="BMW", color='r')
#       5
#       6 x2 = [.75,1.75,2.75,3.75,4.75]
#
# NameError: name 'plt' is not defined
