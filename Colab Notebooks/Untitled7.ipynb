# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use ('ggplot')

import nltk

# %%
df = pd.read_csv('../Users/rohithprajapati/Downloads/Reviews.csv')
print(df.shape)
df = df.head(500)
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-66f9357d2abb> in <cell line: 1>()
# ----> 1 df = pd.read_csv('../Users/rohithprajapati/Downloads/Reviews.csv')
#       2 print(df.shape)
#       3 df = df.head(500)
#       4 print(df.shape)
#
# NameError: name 'pd' is not defined

# %%
df.head()
