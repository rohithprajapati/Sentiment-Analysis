# %%
a=5
b=6
c=a*b
print(c)
# Out:
# 30

# %%
x=2
y=4
p=x
q=y
print(p, q)
# Out:
# 2 4

# %%
a=int(input("enter any number"))
if a%2==0:
 print(a,"is an odd number")
 else;

   print(a,"is an even number")
# Out:
#   File "<ipython-input-12-d71cba4fad56>", line 4
#     else;
#        ^
# SyntaxError: invalid syntax

# %%
f=open("test.txt",'p')
data=f.read()
print(data)
f.close

# %%
r=open("test.txt",'n')
s.write("hello world\n")
s.write("data to\n")
s.write("text file\n")
s.close()

# %%
x=8
y=10
z=x*y
print(z)
# Out:
# 80

# %%
x=int(input("Enter any number)")
print(x)

Enter any number30 
30
# Out:
#   File "<ipython-input-17-00fd3fb8f95e>", line 2
#     print(x)
#         ^
# SyntaxError: invalid syntax

# %%
x=int(input("Enter any number"))
if x%2==0
   print(x, "is an odd number")
   else:
     print(x, "is an even number")

     Enter any number8
     8 is an even number

# %%
f=open("test.txt",'p')
data=f.read()
print(data)
f.close()

heyy web
im using
python 
files

# %%
s=open("test.txt",'n')
s.wirte("here im reading\n")
s.write("data to \n")
s.write("text file \n")
s.close()

# %%
x=int(input("Ener any number"))
print(x)
# Out:
# Ener any number30
# 30

# %%
a=int(input("Enter any number"))
if  a%4==0:
    print(a, "is an odd number")
    print(a, "is an even number")
# Out:
# Enter any number9

# %%
f=open("test.txt",'r')
data=f.read()
print(data)
f.close()

   heyy web
   i'm using
   python
   files

# %%
s=open("test.txt",'b')
s.write("im writing \n")
s.write("data to \n")
s.write("test.txt \n")
s.close()
